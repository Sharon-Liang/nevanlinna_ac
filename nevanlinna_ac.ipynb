# %%
using nevanlinna_ac, Plots, DelimitedFiles

# %%
A1data = readdlm("/Users/liangshuang/Desktop/CAS-code/nevanlinna_ac/data/gaussian/A_delta_eta_0.05.txt")
ωlist = A1data[:,1]
A1 = A1data[:, 2]
x1, y1 = readGF("/Users/liangshuang/Desktop/CAS-code/nevanlinna_ac/data/gaussian/giwn_delta_eta_0.05.txt");

# %%
wlist, A1ac = spectral_function(Fermi, x1, y1, toreverse = false);

# %%
p1 = plot(ωlist, A1, line=2, label="exact")
plot!(wlist, A1ac, line=(1,:dash), marker=2, label="ac")

# %%
ωlist
