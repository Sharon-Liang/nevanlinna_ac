# %%
using nevanlinna_ac, Plots, DelimitedFiles

# %%
A1data = readdlm("/Users/liangshuang/Desktop/CAS-code/nevanlinna_ac/data/gaussian/A_gaussian_1.txt")
ωlist = A1data[:,1]
A1 = A1data[:, 2]
x1, y1 = readGF("/Users/liangshuang/Desktop/CAS-code/nevanlinna_ac/data/gaussian/giwn_gaussian_1.txt");

# %%
A1ac, _ = spectrum(ωlist, 1.e-5, x1, y1, :f);

# %%
p1 = plot(ωlist, A1, line=2, label="exact")
plot!(ωlist, A1ac, line=(1,:dash), marker=2, label="ac")
